# %%
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import (
    train_test_split,
    KFold
)
import tensorflow.keras as keras

# %%
df = pd.read_csv('star_classification.csv')

# %%
df = df.drop(columns='obj_ID').copy()
df = df.sample(frac=1)

# %%
#classes to numeric
df['class'] = pd.factorize(df['class'],sort=True)[0]
df.columns
df = df[[
    'alpha', 'delta', 'u', 'g', 'r', 'i', 'z',
        'class', 'redshift',
]].copy()
df.reset_index(drop=True)
# Out:
#             alpha      delta         u         g         r         i  \
# 0       55.535478  -7.419643  20.29541  19.37658  19.08551  18.95750
# 1      232.396001  44.922834  22.40914  22.04334  20.38544  19.32703
# 2      337.779023   3.407239  22.10592  20.29425  18.60241  17.95621
# 3      197.496547   3.179956  27.42338  23.23021  20.05631  19.01015
# 4      231.561866   5.124304  20.29749  19.02776  18.39364  18.49664
# ...           ...        ...       ...       ...       ...       ...
# 99995  152.707513  36.201460  23.82574  23.04710  21.73759  20.44109
# 99996  145.969452  53.451452  18.05282  16.92962  16.55412  16.28450
# 99997  237.789078  56.208654  20.63028  18.44084  17.22245  16.75003
# 99998   18.572363  -9.326282  18.10073  17.68520  17.88522  18.11217
# 99999  198.054715  35.246631  25.33350  22.02733  20.24579  19.30918
#
#               z  class  redshift
# 0      18.83989      2 -0.000464
# 1      18.81698      0  0.508381
# 2      17.50977      0  0.299698
# 3      18.39571      0  0.577901
# 4      18.02032      2 -0.000157
# ...         ...    ...       ...
# 99995  19.72368      0  0.865028
# 99996  16.12283      0  0.044824
# 99997  16.39925      0  0.178231
# 99998  18.41705      2  0.000124
# 99999  18.73928      0  0.511281
#
# [100000 rows x 9 columns]

# %%
pt = df['class'].value_counts()
pt.plot(kind = 'bar')
pt
# Out:
# 0    59445
# 2    21594
# 1    18961
# Name: class, dtype: int64

# %%
snspair = df[['delta', 'alpha','redshift','u']][:1000]
sns.pairplot(data=snspair,vars=['delta', 'alpha','redshift','u'])

# %%
corr = df[['delta', 'alpha','redshift','u']].corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
features = df[[
    'alpha', 'delta', 'u', 'g', 'r', 'i', 'z','redshift',
]]

classes = df['class'].copy().to_numpy()

# %%
# one hot encode !!
zr_arr = np.zeros((classes.size,df['class'].nunique()))
zr_arr[np.arange(classes.size),np.hstack(classes)] = 1
classes = zr_arr
# Out:
# [1. 1. 1. ... 1. 1. 1.]

# %%
# xtr, xtst, ytr, ytst = train_test_split(features,classes,test_size=0.15)

# %%
kf = KFold(n_splits=10)

for test_idx, train_idx in kf.get_n_splits(features):
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [36], in <cell line: 3>()
#       1 kf = KFold(n_splits=10)
# ----> 3 for test_idx, train_idx in kf.get_n_splits(features):
#       4     pass
#
# TypeError: 'int' object is not iterable

# %%
# model = keras.models.Sequential()
# model.add(
#     keras.layers.Flatten()
# )

# model.add(
#     keras.layers.Dense(
#         50, activation = keras.activations.relu    
#     )
# )

# model.add(
#     keras.layers.Dense(
#         80, activation = keras.activations.sigmoid
#     )
# )

# model.add(
#     keras.layers.Dense(
#         3, activation = keras.activations.softmax
#     )
# )

# loss = keras.losses.CategoricalCrossentropy()

# model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),loss=loss,metrics=[
#     keras.metrics.CategoricalAccuracy(),
# ])

# ft = model.fit(xtr,ytr,epochs=10000,batch_size=10000,verbose=2)
# a = model.evaluate(xtst,ytst,verbose=2)

# ax = ['categorical_accuracy','loss']
# sns.lineplot(ft.history['categorical_accuracy'],color = 'red',label ='categorical_accuracy' )
# sns.lineplot(ft.history['loss'],label = 'loss')
